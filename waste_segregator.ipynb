# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Unzip images and labels(annotations) file to Acned folder in my drive

# %%
# %cd /content/gdrive/MyDrive/waste/

# !unzip /content/gdrive/MyDrive/wastedataset.zip -d .
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./wastedataset/train/labels/glass2270_jpg.rf.be600719d6d385f535a38872b61615b2.txt
#   inflating: ./wastedataset/train/labels/glass2272_jpg.rf.9d3514db458348c302c6e72c8855337b.txt
#   inflating: ./wastedataset/train/labels/glass2273_jpg.rf.e9f67457dd4f2295ee2b138783eadb07.txt
#   inflating: ./wastedataset/train/labels/glass2275_jpg.rf.ce2c94516352e4cb302c7374be55d192.txt
#   inflating: ./wastedataset/train/labels/glass2276_jpg.rf.c17c52041aeacc03ea4911073ba99314.txt
#   inflating: ./wastedataset/train/labels/glass2279_jpg.rf.8652a1ba98d78f8696f77f3fdd9c371e.txt
#   inflating: ./wastedataset/train/labels/glass2280_jpg.rf.0c136fc1e6c24612cfb7582899c99ff3.txt
#   inflating: ./wastedataset/train/labels/glass2281_jpg.rf.48a782790d313e7f1d1709419273ff52.txt
#   inflating: ./wastedataset/train/labels/glass2282_jpg.rf.26066104984eebbaaab8008af2b60e62.txt
# ...

# %%
ROOT_DIR = '/content/gdrive/MyDrive/wastedataset/'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.8/750.8 kB 14.5 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %% [markdown]
# # Model Training using colab Gpus upto 250 itterations

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=60)  # train the model
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import os
from ultralytics import YOLO
confidence_threshold = 0.5
model = YOLO("/content/gdrive/MyDrive/waste/runs/detect/train/weights/last.pt")
results = model("/content/gdrive/MyDrive/wastedataset/valid/images/glass1831_jpg.rf.afdafbaa7e0cc39e606bf19c34d122cb.jpg", conf=confidence_threshold)
# Out:
# image 1/1 /content/gdrive/MyDrive/wastedataset/valid/images/glass1831_jpg.rf.afdafbaa7e0cc39e606bf19c34d122cb.jpg: 640x640 1 GLASS, 14.3ms
# Speed: 3.2ms preprocess, 14.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
